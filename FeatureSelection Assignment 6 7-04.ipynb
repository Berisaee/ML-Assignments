# %%
import pandas as pd
import numpy as np

# %%
bos = pd.read_csv("C:/Users/Saee Beri/OneDrive/Desktop/Msc Datascience/Sem 2/boston_price_airPol.csv", sep="\s+")
bos.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Saee Beri\AppData\Local\Temp\ipykernel_12204\1549616149.py:1: SyntaxWarning: invalid escape sequence '\s'
#   bos = pd.read_csv("C:/Users/Saee Beri/OneDrive/Desktop/Msc Datascience/Sem 2/boston_price_airPol.csv", sep="\s+")
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
x = bos.iloc[:, :-1]
y = bos['Price']
print(x)
print(y)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 14.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 27.4 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.1 MB 7.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 7.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 7.0 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 5.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.1 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ...

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
SFS1 = SFS(LinearRegression(),
           k_features=(3,11),
           forward= True,
           floating=False,
           cv=0)
SFS1.fit(x,y)
print(SFS1.k_feature_idx_)
# Out:
# (0, 1, 3, 4, 5, 7, 8, 9, 10, 11, 12)

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Saee Beri\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
SFS1 = SFS(LinearRegression(),
           k_features= "best",
           forward= True,
           floating=False,
           cv=0)
SFS1.fit(x,y)
print(SFS1.k_feature_names_)
# Out:
# ('CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT')

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import matplotlib.pyplot as plt
fig1 = plot_sfs(SFS1.get_metric_dict(), kind='std_dev')
plt.title=('sequential forward selection (w.stdErr)')
plt.grid()
plt.show()
# Out:
# c:\Users\Saee Beri\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:895: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   std_err = scipy.stats.sem(ary)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
SFS1 = SFS(LinearRegression(),
           k_features=(3,11),
           forward= True,
           floating=False,
           cv=0)
SFS1.fit(x,y)
print(SFS1.k_feature_names_)
# Out:
# ('CRIM', 'ZN', 'CHAS', 'NOX', 'RM', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT')

# %%
df = pd.read_csv("C:/Users/Saee Beri/OneDrive/Desktop/Msc Datascience/Sem 2/diabetes.csv")
df2 = df.copy()
print(df2.head)
# Out:
# <bound method NDFrame.head of      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]>

# %%
x = df2.iloc[:,:-1]
y = df2["class"]
print(x)
print(y)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age
# 0       6   148    72    35     0  33.6  0.627   50
# 1       1    85    66    29     0  26.6  0.351   31
# 2       8   183    64     0     0  23.3  0.672   32
# 3       1    89    66    23    94  28.1  0.167   21
# 4       0   137    40    35   168  43.1  2.288   33
# ..    ...   ...   ...   ...   ...   ...    ...  ...
# 763    10   101    76    48   180  32.9  0.171   63
# 764     2   122    70    27     0  36.8  0.340   27
# 765     5   121    72    23   112  26.2  0.245   30
# 766     1   126    60     0     0  30.1  0.349   47
# 767     1    93    70    31     0  30.4  0.315   23
#
# [768 rows x 8 columns]
# 0      tested_positive
# 1      tested_negative
# 2      tested_positive
# 3      tested_negative
# 4      tested_positive
#             ...
# 763    tested_negative
# 764    tested_negative
# 765    tested_negative
# 766    tested_positive
# 767    tested_negative
# Name: class, Length: 768, dtype: object

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
sfsl =SFS(LinearRegression(),
          k_features='best',
          forward=True,
          floating=False,
          cv=0)
sfsl.fit(x,y)
# Out:
# SequentialFeatureSelector(cv=0, estimator=LinearRegression(),
#                           k_features=(1, 13), scoring='r2')
